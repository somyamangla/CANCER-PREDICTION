# %% [markdown]
# <a href="https://colab.research.google.com/github/somyamangla/CANCER-PREDICTION/blob/main/COMPARISON_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SVM:
# KNN:
# RANDOM FOREST:
# LOGISTIC REGRESSION:
# LINEAR REGRESSION:
# XG BOOST:
# GRADIENT BOOSTING:
# NAIVE BAYES:

# %%
models = ["SVM" , "RANDOM FOREST" , "XG BOOST" , "GRADIENT BOOSTING","KNN","NAIVE BAYES","LOGISTIC REGRESSION","LINEAR REGRESSION"]

# %% [markdown]
# BREAST CANCER

# %%
import matplotlib.pyplot as plt

# %%
breast_data = [94.8,88.18,87.4,82.68,98.2,85.8,99.6,88.18]

# %%
cervical_data = [96.15,99.22,99.22,98.73,55.23,81,25.96,98.73]

# %%
plt.plot(models,breast_data)
plt.xticks(rotation = 45) 
plt.show()

# %%
plt.plot(models,cervical_data)
plt.xticks(rotation = 45) 
plt.show()
