# %% [markdown]
# <a href="https://colab.research.google.com/github/somyamangla/CANCER-PREDICTION/blob/main/comaprison_finalllll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
models = ["SVM" , "RANDOM FOREST" , "XG BOOST" , "GRADIENT BOOSTING","KNN","NAIVE BAYES","LOGISTIC REGRESSION","LINEAR REGRESSION"]

# %%
import matplotlib.pyplot as plt

# %%
breast_data = [94.8,88.18,87.4,82.68,96.49,85.8,99.6,88.18]

# %%
cervical_data = [96.15,99.22,99.22,98.73,55.23,81,25.96,98.73]

# %%
lung_data=["SVM" , "RANDOM FOREST" , "XG BOOST" , "GRADIENT BOOSTING","KNN","NAIVE BAYES","LINEAR REGRESSION"]

# %%
lung_data=[96.8,97.0,92.3,74.04,92.35,92.35,0,84.25]

# %%
liver_data=[71.72,68.18,73.73,67.3,51.2,70.79,70.71,57,7]

# %%
import matplotlib 
import numpy as np 
import matplotlib.pyplot as plt 
      
np.random.seed(10**7) 
n_bins = 20
x = np.random.randn(10000, 3) 
      
colors = ['green', 'blue', 'lime'] 
    
plt.hist(x, n_bins, density = True,  
         histtype ='bar', 
         color = colors, 
         label = colors,
         rwidth = 0.5) 
    
plt.legend(prop ={'size': 10}) 
    
plt.title('matplotlib.pyplot.hist() function Example\n\n', 
          fontweight ="bold") 
    
plt.show()

# %%
colors = ['green', 'blue', 'lime',]

# %%
X_axis = np.arange(len(models))
plt.bar(X_axis+0.2, breast_data,0.4,label='breast_data')
plt.bar(X_axis-0.2, cervical_data,0.4,label='cervical_data')
plt.xticks(X_axis,models)
plt.legend()
plt.xlabel("Algorithms")
plt.xticks(rotation = 90) 
plt.show()

# %%
plt.bar(models, breast_data,0.4,label='breast_data')
plt.xlabel("Algorithms")
plt.xticks(rotation = 90) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
  
N = 4
ind = np.arange(N) 
width = 0.25

bar1 = plt.bar(ind, breast_data, width, color = 'r')
  

bar2 = plt.bar(ind+width, cervical_data, width, color='g')

bar3 = plt.bar(ind+width*2, lung_data, width, color = 'b')
bar4 = plt.bar(ind+width*3, liver_data, width, color = 'b')
  
plt.xlabel("Dates")
plt.ylabel('Scores')
plt.title("Players Score")
  
plt.xticks(ind+width,['2021Feb01', '2021Feb02', '2021Feb03'])
plt.legend( (bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-9b115948201a> in <module>
#       6 width = 0.25
#       7
# ----> 8 bar1 = plt.bar(ind, breast_data, width, color = 'r')
#       9
#      10
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
import pandas as pd

plotdata = pd.DataFrame({

    "Breast cancer":[98.24,88.18,87.4,82.68,96.49,85.8,98.77,88.18],

    "Lung Cancer":[96.8,92.3,92.3,92.35,97,84.25,0,74.04],

    "Liver Cancer":[71.72,73.73,70.79,70.71,68.18,57.7,67.13,51.2],
    "Cervical Cancer":[96.15,99.22,99.22,98.73,55.23,96.5,25.96,98.73]},

    index=["SVM" , "RANDOM FOREST" , "XG BOOST" , "GRADIENT BOOSTING","KNN","NAIVE BAYES","LOGISTIC REGRESSION","LINEAR REGRESSION"])

plotdata.plot(kind="bar",figsize=(15, 10))

plt.title("Accuracy Comparison")

plt.xlabel("Algorithms")

plt.ylabel("Accuracy Score ")
# Out:
# Text(0, 0.5, 'Accuracy Score ')
